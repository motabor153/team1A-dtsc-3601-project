# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\tasho\Downloads\repeat_victims_data.csv')
df
# Out:
#             DR_NO   Date Rptd    DATE OCC  TIME OCC  AREA  AREA NAME  \
# 0       202008217  2020-04-02  2020-03-29      1700    20    Olympic
# 1       202011553  2020-06-29  2020-06-28      1900    20    Olympic
# 2       200108033  2020-02-28  2020-02-28       145     1    Central
# 3       200117379  2020-09-03  2020-09-03       840     1    Central
# 4       201806260  2020-02-09  2020-02-09       900    18  Southeast
# ...           ...         ...         ...       ...   ...        ...
# 732887  240106960  2024-02-11  2024-02-11      1240     1    Central
# 732888  240505693  2024-02-14  2024-02-14      1813     5     Harbor
# 732889  240506539  2024-03-06  2024-03-06      1410     5     Harbor
# 732890  240305318  2024-01-25  2024-01-25      1120     3  Southwest
# 732891  240309207  2024-04-14  2024-04-13       730     3  Southwest
#
#         Part 1-2  Crm Cd                                        Crm Cd Desc  \
# ...

# %%
df.columns.tolist()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA',
#  'AREA NAME',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Vict Age',
#  'Premis Cd',
#  'Premis Desc',
#  'LOCATION',
#  'LAT',
#  'LON',
#  'Vict_Sex_Clean',
#  'Vict_Descent_Clean',
#  'Weapon_Category',
#  'involved_physical_force',
#  'involved_victim_restraint',
#  'showed_planning_or_stealth',
#  'Incident_Year',
#  'Birth_Year',
#  'Victim_ID',
#  'Victim_Incident_Count',
#  'Is_Severe_Assault']

# %%
# Separate your predictors (X) and your target variable (y)
X = df.drop(columns=['Is_Severe_Assault', 'DR_NO', 'DATE OCC', 'Victim_ID']) # Drop IDs and the target
y = df['Is_Severe_Assault']

# One-hot encode the categorical features
X_encoded = pd.get_dummies(X, columns=['AREA NAME', 'Crm Cd Desc', 'Premis Desc', 'Vict_Sex_Clean', 'Vict_Descent_Clean', 'Weapon_Category'], drop_first=True)

# Note: You'll also want to scale your numeric features like 'Vict Age' and 'TIME OCC'
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_encoded[['Vict Age', 'TIME OCC']] = scaler.fit_transform(X_encoded[['Vict Age', 'TIME OCC']])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.3, random_state=42, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Initialize the model
# class_weight='balanced' helps with the imbalanced target variable
##log_reg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# Train the model on your training data
# Drop the 'Date Rptd' and 'LOCATION' columns as they are not numerical features
##X_train_numeric = X_train.drop(columns=['Date Rptd', 'LOCATION'])
#log_reg.fit(X_train_numeric, y_train)

# Make predictions on the test data
# Drop the 'Date Rptd' and 'LOCATION' columns from the test data as well
#X_test_numeric = X_test.drop(columns=['Date Rptd', 'LOCATION'])
#y_pred = log_reg.predict(X_test_numeric)

# Print the performance report
#print("Logistic Regression Baseline Performance:")
#print(classification_report(y_test, y_pred))

# %%
# Create a copy of df with selected columns
df2 = df[['Vict_Descent_Clean', 'Weapon_Category', 'involved_physical_force', 'involved_victim_restraint', 'showed_planning_or_stealth', 'Incident_Year', 'Birth_Year', 'Victim_ID', 'Victim_Incident_Count', 'Is_Severe_Assault']].copy()

# One-hot encode the categorical features
df2_encoded = pd.get_dummies(df2, columns=['Vict_Descent_Clean', 'Weapon_Category'], drop_first=True)

# Separate predictors (X) and target variable (y)
X = df2_encoded.drop(columns=['Is_Severe_Assault', 'Victim_ID']) # Drop ID and the target
y = df2_encoded['Is_Severe_Assault']

# Split into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Create, train, and evaluate a baseline logistic regression model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Initialize the model
log_reg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# Train the model on your training data
log_reg.fit(X_train, y_train)

# Make predictions on the test data
y_pred = log_reg.predict(X_test)

# Print the performance report
print("Logistic Regression Baseline Performance:")
print(classification_report(y_test, y_pred))
# Out:
# c:\Users\tasho\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Baseline Performance:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95    143893
#            1       0.92      0.90      0.91     75975
#
#     accuracy                           0.94    219868
#    macro avg       0.94      0.93      0.93    219868
# weighted avg       0.94      0.94      0.94    219868

# %%
from sklearn.dummy import DummyClassifier

# Majority class baseline model
majority_clf = DummyClassifier(strategy='most_frequent', random_state=42)
majority_clf.fit(X_train, y_train)

# Predict and evaluate
y_majority_pred = majority_clf.predict(X_test)
print("Majority Class Baseline Performance:")
print(classification_report(y_test, y_majority_pred))
# Out:
# Majority Class Baseline Performance:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79    143893
#            1       0.00      0.00      0.00     75975
#
#     accuracy                           0.65    219868
#    macro avg       0.33      0.50      0.40    219868
# weighted avg       0.43      0.65      0.52    219868
# c:\Users\tasho\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\tasho\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
df2_encoded = pd.read_csv(r'C:\Users\mat\Desktop\DTSC 3601\team1A-dtsc-3601-project\data\df2_encoded.csv')
df2_encoded
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df2_encoded = pd.read_csv(r'C:\Users\mat\Desktop\DTSC 3601\team1A-dtsc-3601-project\data\df2_encoded.csv')
#       2 df2_encoded
#
# ...

# %%
df3 = pd.read_csv(r'C:\Users\mat\Desktop\DTSC 3601\team1A-dtsc-3601-project\data\df3.csv')
df3
# Out:
#         involved_physical_force  involved_victim_restraint  \
# 0                             0                          0
# 1                             0                          0
# 2                             0                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 732887                        0                          0
# 732888                        1                          0
# 732889                        0                          0
# 732890                        1                          0
# 732891                        0                          0
#
#         showed_planning_or_stealth  Incident_Year  Birth_Year  \
# 0                                0           2020        1921
# 1                                0           2020        1921
# 2                                0           2020        1921
# ...

# %%
modeling_df=pd.read_csv(r'C:\Users\mat\Desktop\DTSC 3601\team1A-dtsc-3601-project\data\modeling_df.csv')
modeling_df
# Out:
#         involved_physical_force  involved_victim_restraint  \
# 0                             0                          0
# 1                             0                          0
# 2                             1                          0
# 3                             1                          0
# 4                             1                          0
# ...                         ...                        ...
# 716846                        0                          0
# 716847                        1                          0
# 716848                        0                          0
# 716849                        1                          0
# 716850                        1                          0
#
#         showed_planning_or_stealth  Incident_Year  Birth_Year  \
# 0                                0           2020        1921
# 1                                0           2020        1921
# 2                                0           2020        1921
# ...
