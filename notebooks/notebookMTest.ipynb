# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mat\Desktop\DTSC 3601\team1A-dtsc-3601-project\data\Crime_Data_from_2020_to_Present.csv")
df
# Out:
#              DR_NO        Date Rptd         DATE OCC  TIME OCC  AREA  \
# 0        211507896   4/11/2021 0:00   11/7/2020 0:00       845    15
# 1        201516622  10/21/2020 0:00  10/18/2020 0:00      1845    15
# 2        240913563  12/10/2024 0:00  10/30/2020 0:00      1240     9
# 3        210704711  12/24/2020 0:00  12/24/2020 0:00      1310     7
# 4        201418201   10/3/2020 0:00   9/29/2020 0:00      1830    14
# ...            ...              ...              ...       ...   ...
# 1004986  252104112    2/2/2025 0:00    2/2/2025 0:00       130    21
# 1004987  250404100   2/18/2025 0:00   2/18/2025 0:00      1000     4
# 1004988  251304095   1/31/2025 0:00   1/30/2025 0:00      1554    13
# 1004989  251704066   1/17/2025 0:00   1/17/2025 0:00      1600    17
# 1004990  251904210   3/25/2025 0:00   3/25/2025 0:00      1235    19
#
#            AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0        N Hollywood         1502         2     354
# 1        N Hollywood         1521         1     230
# 2           Van Nuys          933         2     354
# 3           Wilshire          782         1     331
# 4            Pacific         1454         1     420
# ...              ...          ...       ...     ...
# 1004986      Topanga         2103         2     946
# 1004987   Hollenbeck          479         2     237
# 1004988       Newton         1372         2     850
# 1004989   Devonshire         1774         2     624
# 1004990      Mission         1944         2     850
#
#                                                Crm Cd Desc  ... Status  \
# 0                                        THEFT OF IDENTITY  ...     IC
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 2                                        THEFT OF IDENTITY  ...     IC
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...     IC
# 4          THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# ...                                                    ...  ...    ...
# 1004986                          OTHER MISCELLANEOUS CRIME  ...     IC
# 1004987                     CHILD NEGLECT (SEE 300 W.I.C.)  ...     IC
# 1004988                                  INDECENT EXPOSURE  ...     IC
# 1004989                           BATTERY - SIMPLE ASSAULT  ...     IC
# 1004990                                  INDECENT EXPOSURE  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Invest Cont    354.0      NaN       NaN      NaN
# 1        Invest Cont    230.0      NaN       NaN      NaN
# 2        Invest Cont    354.0      NaN       NaN      NaN
# 3        Invest Cont    331.0      NaN       NaN      NaN
# 4        Invest Cont    420.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 1004986  Invest Cont    946.0      NaN       NaN      NaN
# 1004987  Invest Cont    237.0      NaN       NaN      NaN
# 1004988  Invest Cont    850.0      NaN       NaN      NaN
# 1004989  Invest Cont    624.0      NaN       NaN      NaN
# 1004990  Invest Cont    850.0      NaN       NaN      NaN
#
#                                          LOCATION Cross Street      LAT  \
# 0         7800    BEEMAN                       AV          NaN  34.2124
# 1                 ATOLL                        AV     N  GAULT  34.1993
# 2        14600    SYLVAN                       ST          NaN  34.1847
# 3         6000    COMEY                        AV          NaN  34.0339
# 4                         4700    LA VILLA MARINA          NaN  33.9813
# ...                                           ...          ...      ...
# 1004986  22100    ROSCOE                       BL          NaN  34.2259
# 1004987   3500    PERCY                        ST          NaN  34.0277
# 1004988    300 E  53RD                         ST          NaN  33.9942
# 1004989   9600    ZELZAH                       AV          NaN  34.2450
# 1004990  11100    OMELVENY                     AV          NaN  34.2722
#
#               LON
# 0       -118.4092
# 1       -118.4203
# 2       -118.4509
# 3       -118.3747
# 4       -118.4350
# ...           ...
# 1004986 -118.6126
# 1004987 -118.1979
# 1004988 -118.2701
# 1004989 -118.5233
# 1004990 -118.4417
#
# [1004991 rows x 28 columns]

# %%
vict_sex_counts = df['Vict Sex'].value_counts()
print(vict_sex_counts[['M', 'F']])
# Out:
# Vict Sex
# M    403879
# F    358580
# Name: count, dtype: int64

# %% [markdown]
# Cleaning

# %%
# Dropping all unneeded columns so far
df = df.drop(columns=['Status', 'Status Desc', 'Crm Cd 1', 'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'Rpt Dist No', 'Cross Street'])

# Converting from string to datetime
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])

# Filter out rows where Vict Age is 0 (and other demographics are likely missing)
df_v2 = df[df['Vict Age'] > 0].copy()
df_v2
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  Vict Age Vict Sex  \
# 0                                            377        31        M
# 1        0416 0334 2004 1822 1414 0305 0319 0400        32        M
# 2                                            377        30        M
# 3                                            344        47        F
# 4                            1300 0344 1606 2032        63        M
# ...                                          ...       ...      ...
# 1004986                                      NaN        35        M
# 1004987                           1258 0553 0602        11        M
# 1004988                                      NaN        16        F
# 1004989                      0400 1259 1822 0356        17        M
# 1004990                      0529 2024 1815 0913        35        F
#
#         Vict Descent  Premis Cd             Premis Desc  Weapon Used Cd  \
# 0                  H      501.0  SINGLE FAMILY DWELLING             NaN
# 1                  H      102.0                SIDEWALK           200.0
# 2                  W      501.0  SINGLE FAMILY DWELLING             NaN
# 3                  A      101.0                  STREET             NaN
# 4                  H      103.0                   ALLEY             NaN
# ...              ...        ...                     ...             ...
# 1004986            X      101.0                  STREET             NaN
# 1004987            B      501.0  SINGLE FAMILY DWELLING             NaN
# 1004988            H      101.0                  STREET             NaN
# 1004989            H      721.0             HIGH SCHOOL           400.0
# 1004990            H      721.0             HIGH SCHOOL             NaN
#
#                                             Weapon Desc  \
# 0                                                   NaN
# 1                      KNIFE WITH BLADE 6INCHES OR LESS
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1004986                                             NaN
# 1004987                                             NaN
# 1004988                                             NaN
# 1004989  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990                                             NaN
#
#                                          LOCATION      LAT       LON
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
# [735632 rows x 20 columns]

# %%
print(df[['Vict Age', 'Vict Sex', 'Vict Descent']].isnull().sum())
# Out:
# Vict Age             0
# Vict Sex        144644
# Vict Descent    144656
# dtype: int64

# %%
print(df['Vict Sex'].unique())
# Out:
# ['M' 'F' nan 'X' 'H' '-']

# %%
# Fixing 'Vict Sex'
sex_map = {
    'M': 'Male',
    'F': 'Female',
    'X': 'Unknown/Other',
    'H': 'Unknown/Other', # Grouping non-standard codes
    '-': 'Unknown/Other'  # Grouping placeholders
}

# Create a new cleaned column
df_v2['Vict_Sex_Clean'] = df_v2['Vict Sex'].map(sex_map)

# Fill any remaining missing values (the original 'nan's)
df_v2['Vict_Sex_Clean'].fillna('Unknown/Other', inplace=True)

print(df_v2['Vict_Sex_Clean'].value_counts())

df_v2
# Out:
# Vict_Sex_Clean
# Male             370293
# Female           354689
# Unknown/Other     10650
# Name: count, dtype: int64
# C:\Users\mat\AppData\Local\Temp\ipykernel_17636\2417656124.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_v2['Vict_Sex_Clean'].fillna('Unknown/Other', inplace=True)
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  ...  Vict Sex Vict Descent  \
# 0                                            377  ...         M            H
# 1        0416 0334 2004 1822 1414 0305 0319 0400  ...         M            H
# 2                                            377  ...         M            W
# 3                                            344  ...         F            A
# 4                            1300 0344 1606 2032  ...         M            H
# ...                                          ...  ...       ...          ...
# 1004986                                      NaN  ...         M            X
# 1004987                           1258 0553 0602  ...         M            B
# 1004988                                      NaN  ...         F            H
# 1004989                      0400 1259 1822 0356  ...         M            H
# 1004990                      0529 2024 1815 0913  ...         F            H
#
#         Premis Cd             Premis Desc Weapon Used Cd  \
# 0           501.0  SINGLE FAMILY DWELLING            NaN
# 1           102.0                SIDEWALK          200.0
# 2           501.0  SINGLE FAMILY DWELLING            NaN
# 3           101.0                  STREET            NaN
# 4           103.0                   ALLEY            NaN
# ...           ...                     ...            ...
# 1004986     101.0                  STREET            NaN
# 1004987     501.0  SINGLE FAMILY DWELLING            NaN
# 1004988     101.0                  STREET            NaN
# 1004989     721.0             HIGH SCHOOL          400.0
# 1004990     721.0             HIGH SCHOOL            NaN
#
#                                             Weapon Desc  \
# 0                                                   NaN
# 1                      KNIFE WITH BLADE 6INCHES OR LESS
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1004986                                             NaN
# 1004987                                             NaN
# 1004988                                             NaN
# 1004989  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990                                             NaN
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean
# 0                  Male
# 1                  Male
# 2                  Male
# 3                Female
# 4                  Male
# ...                 ...
# 1004986            Male
# 1004987            Male
# 1004988          Female
# 1004989            Male
# 1004990          Female
#
# [735632 rows x 21 columns]

# %%
df_v2.drop(columns=['Vict Sex'], inplace=True)
df_v2
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  Vict Age Vict Descent  \
# 0                                            377        31            H
# 1        0416 0334 2004 1822 1414 0305 0319 0400        32            H
# 2                                            377        30            W
# 3                                            344        47            A
# 4                            1300 0344 1606 2032        63            H
# ...                                          ...       ...          ...
# 1004986                                      NaN        35            X
# 1004987                           1258 0553 0602        11            B
# 1004988                                      NaN        16            H
# 1004989                      0400 1259 1822 0356        17            H
# 1004990                      0529 2024 1815 0913        35            H
#
#          Premis Cd             Premis Desc  Weapon Used Cd  \
# 0            501.0  SINGLE FAMILY DWELLING             NaN
# 1            102.0                SIDEWALK           200.0
# 2            501.0  SINGLE FAMILY DWELLING             NaN
# 3            101.0                  STREET             NaN
# 4            103.0                   ALLEY             NaN
# ...            ...                     ...             ...
# 1004986      101.0                  STREET             NaN
# 1004987      501.0  SINGLE FAMILY DWELLING             NaN
# 1004988      101.0                  STREET             NaN
# 1004989      721.0             HIGH SCHOOL           400.0
# 1004990      721.0             HIGH SCHOOL             NaN
#
#                                             Weapon Desc  \
# 0                                                   NaN
# 1                      KNIFE WITH BLADE 6INCHES OR LESS
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1004986                                             NaN
# 1004987                                             NaN
# 1004988                                             NaN
# 1004989  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990                                             NaN
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#         Vict_Sex_Clean
# 0                 Male
# 1                 Male
# 2                 Male
# 3               Female
# 4                 Male
# ...                ...
# 1004986           Male
# 1004987           Male
# 1004988         Female
# 1004989           Male
# 1004990         Female
#
# [735632 rows x 20 columns]

# %%
print(df['Vict Descent'].unique())
# Out:
# ['H' 'W' 'A' 'B' nan 'X' 'O' 'C' 'J' 'V' 'K' 'F' 'I' 'Z' 'L' 'G' 'P' 'D'
#  'U' 'S' '-']

# %%
df_v3 = df_v2.copy()

# %%
# Fixing 'Vict Descent'
# Based on common LAPD and other crime data dictionaries
descent_map = {
    'H': 'Hispanic',
    'W': 'White',
    'B': 'Black',
    'A': 'Asian',
    'C': 'Other/Unknown', # Chinese
    'D': 'Other/Unknown', # Cambodian
    'F': 'Other/Unknown', # Filipino
    'G': 'Other/Unknown', # Guamanian
    'I': 'Other/Unknown', # American Indian/Alaskan Native
    'J': 'Other/Unknown', # Japanese
    'K': 'Other/Unknown', # Korean
    'L': 'Other/Unknown', # Laotian
    'O': 'Other/Unknown', # Other
    'P': 'Other/Unknown', # Pacific Islander
    'S': 'Other/Unknown', # Samoan
    'U': 'Other/Unknown', # Hawaiian
    'V': 'Other/Unknown', # Vietnamese
    'X': 'Other/Unknown', # Unknown
    'Z': 'Other/Unknown', # Asian Indian
    '-': 'Other/Unknown'  # Placeholder for missing
}

# Create the new cleaned column
df_v3['Vict_Descent_Clean'] = df_v3['Vict Descent'].map(descent_map)

# Fill any remaining missing values (the original 'nan's)
df_v3['Vict_Descent_Clean'].fillna('Other/Unknown', inplace=True)

print(df_v3['Vict_Descent_Clean'].value_counts())
# Out:
# Vict_Descent_Clean
# Hispanic         291535
# White            186531
# Black            134254
# Other/Unknown    102308
# Asian             21004
# Name: count, dtype: int64
# C:\Users\mat\AppData\Local\Temp\ipykernel_17636\226598849.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_v3['Vict_Descent_Clean'].fillna('Other/Unknown', inplace=True)

# %%
df_v3
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  ...  Vict Descent Premis Cd  \
# 0                                            377  ...             H     501.0
# 1        0416 0334 2004 1822 1414 0305 0319 0400  ...             H     102.0
# 2                                            377  ...             W     501.0
# 3                                            344  ...             A     101.0
# 4                            1300 0344 1606 2032  ...             H     103.0
# ...                                          ...  ...           ...       ...
# 1004986                                      NaN  ...             X     101.0
# 1004987                           1258 0553 0602  ...             B     501.0
# 1004988                                      NaN  ...             H     101.0
# 1004989                      0400 1259 1822 0356  ...             H     721.0
# 1004990                      0529 2024 1815 0913  ...             H     721.0
#
#                     Premis Desc Weapon Used Cd  \
# 0        SINGLE FAMILY DWELLING            NaN
# 1                      SIDEWALK          200.0
# 2        SINGLE FAMILY DWELLING            NaN
# 3                        STREET            NaN
# 4                         ALLEY            NaN
# ...                         ...            ...
# 1004986                  STREET            NaN
# 1004987  SINGLE FAMILY DWELLING            NaN
# 1004988                  STREET            NaN
# 1004989             HIGH SCHOOL          400.0
# 1004990             HIGH SCHOOL            NaN
#
#                                             Weapon Desc  \
# 0                                                   NaN
# 1                      KNIFE WITH BLADE 6INCHES OR LESS
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1004986                                             NaN
# 1004987                                             NaN
# 1004988                                             NaN
# 1004989  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990                                             NaN
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean Vict_Descent_Clean
# 0                  Male           Hispanic
# 1                  Male           Hispanic
# 2                  Male              White
# 3                Female              Asian
# 4                  Male           Hispanic
# ...                 ...                ...
# 1004986            Male      Other/Unknown
# 1004987            Male              Black
# 1004988          Female           Hispanic
# 1004989            Male           Hispanic
# 1004990          Female           Hispanic
#
# [735632 rows x 21 columns]

# %%
print(df['Weapon Desc'].unique())
# Out:
# [nan 'KNIFE WITH BLADE 6INCHES OR LESS' 'UNKNOWN WEAPON/OTHER WEAPON'
#  'STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)'
#  'AIR PISTOL/REVOLVER/RIFLE/BB GUN' 'HAND GUN' 'UNKNOWN FIREARM'
#  'VERBAL THREAT' 'SEMI-AUTOMATIC PISTOL' 'STICK' 'OTHER KNIFE'
#  'KNIFE WITH BLADE OVER 6 INCHES IN LENGTH' 'MACE/PEPPER SPRAY'
#  'FOLDING KNIFE' 'PIPE/METAL PIPE' 'ROCK/THROWN OBJECT' 'RIFLE' 'FIRE'
#  'REVOLVER' 'VEHICLE' 'BOTTLE' 'RAZOR' 'SIMULATED GUN' 'BRASS KNUCKLES'
#  'UNKNOWN TYPE CUTTING INSTRUMENT' 'KITCHEN KNIFE' 'BLUNT INSTRUMENT'
#  'OTHER FIREARM' 'CLUB/BAT' 'HAMMER' 'STUN GUN' 'RAZOR BLADE'
#  'BELT FLAILING INSTRUMENT/CHAIN' 'SCREWDRIVER' 'SHOTGUN'
#  'CONCRETE BLOCK/BRICK' 'PHYSICAL PRESENCE' 'MACHETE'
#  'CAUSTIC CHEMICAL/POISON' 'SCALDING LIQUID' 'OTHER CUTTING INSTRUMENT'
#  'BOWIE KNIFE' 'GLASS' 'TOY GUN' 'FIXED OBJECT' 'AXE' 'BOARD'
#  'BOMB THREAT' 'SCISSORS' 'ROPE/LIGATURE' 'TIRE IRON' 'SWORD'
#  'SWITCH BLADE' 'SYRINGE' 'SEMI-AUTOMATIC RIFLE' 'BOW AND ARROW'
#  'HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE' 'CLEAVER'
#  'DOG/ANIMAL (SIC ANIMAL ON)' 'SAWED OFF RIFLE/SHOTGUN' 'BLACKJACK'
#  'ASSAULT WEAPON/UZI/AK47/ETC' 'EXPLOXIVE DEVICE' 'LIQUOR/DRUGS'
#  'RELIC FIREARM' 'AUTOMATIC WEAPON/SUB-MACHINE GUN'
#  'HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE' 'DEMAND NOTE' 'ICE PICK'
#  'DIRK/DAGGER' 'MARTIAL ARTS WEAPONS' 'STRAIGHT RAZOR'
#  'STARTER PISTOL/REVOLVER' 'UZI SEMIAUTOMATIC ASSAULT RIFLE'
#  'MAC-11 SEMIAUTOMATIC ASSAULT WEAPON' 'ANTIQUE FIREARM'
#  'M1-1 SEMIAUTOMATIC ASSAULT RIFLE' 'MAC-10 SEMIAUTOMATIC ASSAULT WEAPON'
#  'UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE' 'M-14 SEMIAUTOMATIC ASSAULT RIFLE']

# %%
# Fixing 'Vict Descent'
import numpy as np

# Filing missing values. This confirms that the absence of a weapon is the baseline.
df_v3['Weapon Desc'].fillna('None', inplace=True)

# A function that groups the 79 weapon types into a few categories.
def categorize_weapon(description):
    # Handle potential missing values (nan) first
    if not isinstance(description, str):
        return 'None'
    
    # Standardize to uppercase for easier matching
    desc_upper = description.upper()
    
    # --- Category Checks ---
    
    # 1. Firearms (including simulated/toy guns used as threats)
    firearm_keywords = ['GUN', 'PISTOL', 'REVOLVER', 'RIFLE', 'FIREARM', 'SHOTGUN', 
                        'ASSAULT WEAPON', 'UZI', 'AK47', 'MAC-10', 'MAC-11', 'SUB-MACHINE']
    if any(keyword in desc_upper for keyword in firearm_keywords):
        return 'Firearm'

    # 2. Edged Weapons
    edged_keywords = ['KNIFE', 'BLADE', 'RAZOR', 'CUTTING INSTRUMENT', 'MACHETE', 
                      'CLEAVER', 'SWORD', 'ICE PICK', 'DIRK/DAGGER', 'SCISSORS']
    if any(keyword in desc_upper for keyword in edged_keywords):
        return 'Edged Weapon'

    # 3. Bodily Force
    force_keywords = ['STRONG-ARM', 'HANDS', 'FIST', 'FEET', 'BODILY FORCE', 'PHYSICAL PRESENCE']
    if any(keyword in desc_upper for keyword in force_keywords):
        return 'Bodily Force'

    # 4. Threats (Verbal or Written)
    threat_keywords = ['VERBAL THREAT', 'BOMB THREAT', 'DEMAND NOTE']
    if any(keyword in desc_upper for keyword in threat_keywords):
        return 'Threat'
        
    # 5. Unknown Weapons (check this after specific types)
    if 'UNKNOWN' in desc_upper:
        return 'Unknown'
        
    # 6. None (for explicitly stated no-weapon cases)
    if 'NONE' in desc_upper:
        return 'None'

    # 7. If none of the above, classify as Other Weapon
    return 'Other Weapon'

# Create the new column by applying the function
df_v3['Weapon_Category'] = df_v3['Weapon Desc'].apply(categorize_weapon)

# Verify the results
print(df_v3['Weapon_Category'].value_counts())
df_v3
# Out:
# C:\Users\mat\AppData\Local\Temp\ipykernel_17636\3220929462.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_v3['Weapon Desc'].fillna('None', inplace=True)
# Weapon_Category
# None            434713
# Bodily Force    166610
# Firearm          34881
# Unknown          31488
# Other Weapon     24185
# Threat           22274
# Edged Weapon     21481
# Name: count, dtype: int64
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  ...  Premis Cd  \
# 0                                            377  ...      501.0
# 1        0416 0334 2004 1822 1414 0305 0319 0400  ...      102.0
# 2                                            377  ...      501.0
# 3                                            344  ...      101.0
# 4                            1300 0344 1606 2032  ...      103.0
# ...                                          ...  ...        ...
# 1004986                                      NaN  ...      101.0
# 1004987                           1258 0553 0602  ...      501.0
# 1004988                                      NaN  ...      101.0
# 1004989                      0400 1259 1822 0356  ...      721.0
# 1004990                      0529 2024 1815 0913  ...      721.0
#
#                     Premis Desc  Weapon Used Cd  \
# 0        SINGLE FAMILY DWELLING             NaN
# 1                      SIDEWALK           200.0
# 2        SINGLE FAMILY DWELLING             NaN
# 3                        STREET             NaN
# 4                         ALLEY             NaN
# ...                         ...             ...
# 1004986                  STREET             NaN
# 1004987  SINGLE FAMILY DWELLING             NaN
# 1004988                  STREET             NaN
# 1004989             HIGH SCHOOL           400.0
# 1004990             HIGH SCHOOL             NaN
#
#                                             Weapon Desc  \
# 0                                                  None
# 1                      KNIFE WITH BLADE 6INCHES OR LESS
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1004986                                            None
# 1004987                                            None
# 1004988                                            None
# 1004989  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990                                            None
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean  Vict_Descent_Clean Weapon_Category
# 0                  Male            Hispanic            None
# 1                  Male            Hispanic    Edged Weapon
# 2                  Male               White            None
# 3                Female               Asian            None
# 4                  Male            Hispanic            None
# ...                 ...                 ...             ...
# 1004986            Male       Other/Unknown            None
# 1004987            Male               Black            None
# 1004988          Female            Hispanic            None
# 1004989            Male            Hispanic    Bodily Force
# 1004990          Female            Hispanic            None
#
# [735632 rows x 22 columns]

# %% [markdown]
# # Side-By-Side Comparison of Weapon Desc and Weapon_Category

# %%
# Side by side comparison of new column, Weapon_Category and Weapon Desc
df_weapon_check = df_v3[['Weapon_Category', 'Weapon Desc']].copy()
display(df_weapon_check)
# Out:
#         Weapon_Category                                     Weapon Desc
# 0                  None                                            None
# 1          Edged Weapon                KNIFE WITH BLADE 6INCHES OR LESS
# 2                  None                                            None
# 3                  None                                            None
# 4                  None                                            None
# ...                 ...                                             ...
# 1004986            None                                            None
# 1004987            None                                            None
# 1004988            None                                            None
# 1004989    Bodily Force  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# 1004990            None                                            None
#
# [735632 rows x 2 columns]

# %% [markdown]
# # Side-By-Side Comparison of Vict Descent and Vict_Descent_Clean

# %%
# Side by side comparison of new column, Vict Descent and Vict Descent Clean
df_descent2 = pd.DataFrame({
    'Vict Descent': df_v2['Vict Descent'],
    'Vict Descent Clean': df_v3['Vict_Descent_Clean']
})
display(df_descent2)
# Out:
#         Vict Descent Vict Descent Clean
# 0                  H           Hispanic
# 1                  H           Hispanic
# 2                  W              White
# 3                  A              Asian
# 4                  H           Hispanic
# ...              ...                ...
# 1004986            X      Other/Unknown
# 1004987            B              Black
# 1004988            H           Hispanic
# 1004989            H           Hispanic
# 1004990            H           Hispanic
#
# [735632 rows x 2 columns]

# %%
df_v3.drop(columns=['Vict Descent', 'Weapon Desc'], inplace=True)
df_v3
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  Vict Age  Premis Cd  \
# 0                                            377        31      501.0
# 1        0416 0334 2004 1822 1414 0305 0319 0400        32      102.0
# 2                                            377        30      501.0
# 3                                            344        47      101.0
# 4                            1300 0344 1606 2032        63      103.0
# ...                                          ...       ...        ...
# 1004986                                      NaN        35      101.0
# 1004987                           1258 0553 0602        11      501.0
# 1004988                                      NaN        16      101.0
# 1004989                      0400 1259 1822 0356        17      721.0
# 1004990                      0529 2024 1815 0913        35      721.0
#
#                     Premis Desc  Weapon Used Cd  \
# 0        SINGLE FAMILY DWELLING             NaN
# 1                      SIDEWALK           200.0
# 2        SINGLE FAMILY DWELLING             NaN
# 3                        STREET             NaN
# 4                         ALLEY             NaN
# ...                         ...             ...
# 1004986                  STREET             NaN
# 1004987  SINGLE FAMILY DWELLING             NaN
# 1004988                  STREET             NaN
# 1004989             HIGH SCHOOL           400.0
# 1004990             HIGH SCHOOL             NaN
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#         Vict_Sex_Clean Vict_Descent_Clean Weapon_Category
# 0                 Male           Hispanic            None
# 1                 Male           Hispanic    Edged Weapon
# 2                 Male              White            None
# 3               Female              Asian            None
# 4                 Male           Hispanic            None
# ...                ...                ...             ...
# 1004986           Male      Other/Unknown            None
# 1004987           Male              Black            None
# 1004988         Female           Hispanic            None
# 1004989           Male           Hispanic    Bodily Force
# 1004990         Female           Hispanic            None
#
# [735632 rows x 20 columns]

# %%
df_v4 = df_v3.copy()

# %%
# Simplifying 'Mocodes'
# Creating the column 'involved_physical_force' from certain mocodes

# First, ensure your 'Mocodes_List' column exists and is clean
df_v4['Mocodes'].fillna('', inplace=True)
df_v4['Mocodes_List'] = df_v4['Mocodes'].str.split()

# Step 1: Define the list of codes that represent physical force
force_codes = [
    '0356', '0400', '0401', '0406', '0407', '0408', '0413', 
    '0416', '0417', '0419', '0426', '0429', '0430', '0444', 
    '0446', '0447', '0448', '1281', '1601'
]

# Step 2: Write a function to check if any of these codes exist in a list
def check_for_codes(code_list, target_codes):
    # The set intersection is a fast way to check for common elements
    return 1 if set(code_list) & set(target_codes) else 0

# Step 3: Apply this function to create your new feature column
df_v4['involved_physical_force'] = df_v4['Mocodes_List'].apply(lambda x: check_for_codes(x, force_codes))

# Step 4: Verify the result
print(df_v4['involved_physical_force'].value_counts())
# Out:
# C:\Users\mat\AppData\Local\Temp\ipykernel_17636\3674803690.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_v4['Mocodes'].fillna('', inplace=True)
# involved_physical_force
# 0    527985
# 1    207647
# Name: count, dtype: int64

# %%
# Creating the column 'involved_victim_restraint' from certain mocodes
# Re-usable function from the previous example
def check_for_codes(code_list, target_codes):
    """Checks if any target codes are present in a list of codes."""
    return 1 if set(code_list) & set(target_codes) else 0

# Step 1: Define the list of codes that represent victim restraint
restraint_codes = [
    '0341', # Makes vict lie down
    '0402', # Blindfolded
    '0405', # Bound
    '0409', # Cover mouth w/hands
    '0411', # Covered victim's face
    '0414', # Gagged
    '0415', # Handcuffed/Metal
    '0423', # Tied victim to object
    '0435', # Chain
    '0436', # Clothing
    '0437', # Flexcuffs/Plastic Tie
    '0438', # Rope/Cordage
    '0439', # Tape/Electrical etc...
    '0440', # Telephone/Electric Cord
    '0441'  # Wire
]

# Step 2: Apply the function to create your new feature column
df_v4['involved_victim_restraint'] = df_v4['Mocodes_List'].apply(lambda x: check_for_codes(x, restraint_codes))

# Step 3: Verify the result
print("--- 'involved_victim_restraint' Distribution ---")
print(df_v4['involved_victim_restraint'].value_counts())
# Out:
# --- 'involved_victim_restraint' Distribution ---
# involved_victim_restraint
# 0    727042
# 1      8590
# Name: count, dtype: int64

# %%
# Creating the column 'showed_planning_or_stealth' from certain mocodes
# Step 1: Define the specific codes for planning and stalking
planning_codes = [
    '0313', # Hid in building
    '0335', # Cases location
    '0338', # Disables Telephone
    '0339', # Disables video camera
    '0340', # Suspect follows victim/follows victim home
    '0347'  # Stalks vict
]

# Step 2: Write a more specific function for this feature
def check_for_planning(code_list):
    """
    Checks for specific planning codes OR any disguise code (starting with '02').
    """
    # Check for specific planning codes
    if set(code_list) & set(planning_codes):
        return 1
    
    # Check for any disguise code (those in the 0200 series)
    for code in code_list:
        if code.startswith('02'):
            return 1
            
    return 0

# Step 3: Apply this new function to create the feature column
df_v4['showed_planning_or_stealth'] = df_v4['Mocodes_List'].apply(check_for_planning)

# Step 4: Verify the result
print("\n--- 'showed_planning_or_stealth' Distribution ---")
print(df_v4['showed_planning_or_stealth'].value_counts())
# Out:
# --- 'showed_planning_or_stealth' Distribution ---
# showed_planning_or_stealth
# 0    710524
# 1     25108
# Name: count, dtype: int64

# %% [markdown]
# # Side-By-Side Comparison of Mocode and New Columns

# %%
# Side by Side comparison of Mocodes and new columns
df_mocode = df_v4[['Mocodes', 'Mocodes_List', 'involved_physical_force', 'involved_victim_restraint', 'showed_planning_or_stealth']].copy()
display(df_mocode)
# Out:
#                                          Mocodes  \
# 0                                            377
# 1        0416 0334 2004 1822 1414 0305 0319 0400
# 2                                            377
# 3                                            344
# 4                            1300 0344 1606 2032
# ...                                          ...
# 1004986
# 1004987                           1258 0553 0602
# 1004988
# 1004989                      0400 1259 1822 0356
# 1004990                      0529 2024 1815 0913
#
#                                              Mocodes_List  \
# 0                                                   [377]
# 1        [0416, 0334, 2004, 1822, 1414, 0305, 0319, 0400]
# 2                                                   [377]
# 3                                                   [344]
# 4                                [1300, 0344, 1606, 2032]
# ...                                                   ...
# 1004986                                                []
# 1004987                                [1258, 0553, 0602]
# 1004988                                                []
# 1004989                          [0400, 1259, 1822, 0356]
# 1004990                          [0529, 2024, 1815, 0913]
#
#          involved_physical_force  involved_victim_restraint  \
# 0                              0                          0
# 1                              1                          0
# 2                              0                          0
# 3                              0                          0
# 4                              0                          0
# ...                          ...                        ...
# 1004986                        0                          0
# 1004987                        0                          0
# 1004988                        0                          0
# 1004989                        1                          0
# 1004990                        0                          0
#
#          showed_planning_or_stealth
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 1004986                           0
# 1004987                           0
# 1004988                           0
# 1004989                           0
# 1004990                           0
#
# [735632 rows x 5 columns]

# %%
df_v4
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#                                          Mocodes  ...  \
# 0                                            377  ...
# 1        0416 0334 2004 1822 1414 0305 0319 0400  ...
# 2                                            377  ...
# 3                                            344  ...
# 4                            1300 0344 1606 2032  ...
# ...                                          ...  ...
# 1004986                                           ...
# 1004987                           1258 0553 0602  ...
# 1004988                                           ...
# 1004989                      0400 1259 1822 0356  ...
# 1004990                      0529 2024 1815 0913  ...
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean Vict_Descent_Clean  Weapon_Category  \
# 0                  Male           Hispanic             None
# 1                  Male           Hispanic     Edged Weapon
# 2                  Male              White             None
# 3                Female              Asian             None
# 4                  Male           Hispanic             None
# ...                 ...                ...              ...
# 1004986            Male      Other/Unknown             None
# 1004987            Male              Black             None
# 1004988          Female           Hispanic             None
# 1004989            Male           Hispanic     Bodily Force
# 1004990          Female           Hispanic             None
#
#                                              Mocodes_List  \
# 0                                                   [377]
# 1        [0416, 0334, 2004, 1822, 1414, 0305, 0319, 0400]
# 2                                                   [377]
# 3                                                   [344]
# 4                                [1300, 0344, 1606, 2032]
# ...                                                   ...
# 1004986                                                []
# 1004987                                [1258, 0553, 0602]
# 1004988                                                []
# 1004989                          [0400, 1259, 1822, 0356]
# 1004990                          [0529, 2024, 1815, 0913]
#
#         involved_physical_force involved_victim_restraint  \
# 0                             0                         0
# 1                             1                         0
# 2                             0                         0
# 3                             0                         0
# 4                             0                         0
# ...                         ...                       ...
# 1004986                       0                         0
# 1004987                       0                         0
# 1004988                       0                         0
# 1004989                       1                         0
# 1004990                       0                         0
#
#         showed_planning_or_stealth
# 0                                0
# 1                                0
# 2                                0
# 3                                0
# 4                                0
# ...                            ...
# 1004986                          0
# 1004987                          0
# 1004988                          0
# 1004989                          0
# 1004990                          0
#
# [735632 rows x 24 columns]

# %%
df_v4.drop(columns=['Mocodes', 'Mocodes_List'], inplace=True)
df_v4
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#          Vict Age  ...  Weapon Used Cd  \
# 0              31  ...             NaN
# 1              32  ...           200.0
# 2              30  ...             NaN
# 3              47  ...             NaN
# 4              63  ...             NaN
# ...           ...  ...             ...
# 1004986        35  ...             NaN
# 1004987        11  ...             NaN
# 1004988        16  ...             NaN
# 1004989        17  ...           400.0
# 1004990        35  ...             NaN
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean  Vict_Descent_Clean Weapon_Category  \
# 0                  Male            Hispanic            None
# 1                  Male            Hispanic    Edged Weapon
# 2                  Male               White            None
# 3                Female               Asian            None
# 4                  Male            Hispanic            None
# ...                 ...                 ...             ...
# 1004986            Male       Other/Unknown            None
# 1004987            Male               Black            None
# 1004988          Female            Hispanic            None
# 1004989            Male            Hispanic    Bodily Force
# 1004990          Female            Hispanic            None
#
#         involved_physical_force involved_victim_restraint  \
# 0                             0                         0
# 1                             1                         0
# 2                             0                         0
# 3                             0                         0
# 4                             0                         0
# ...                         ...                       ...
# 1004986                       0                         0
# 1004987                       0                         0
# 1004988                       0                         0
# 1004989                       1                         0
# 1004990                       0                         0
#
#          showed_planning_or_stealth
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 1004986                           0
# 1004987                           0
# 1004988                           0
# 1004989                           0
# 1004990                           0
#
# [735632 rows x 22 columns]

# %%
df_v4.columns.tolist()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA',
#  'AREA NAME',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Vict Age',
#  'Premis Cd',
#  'Premis Desc',
#  'Weapon Used Cd',
#  'LOCATION',
#  'LAT',
#  'LON',
#  'Vict_Sex_Clean',
#  'Vict_Descent_Clean',
#  'Weapon_Category',
#  'involved_physical_force',
#  'involved_victim_restraint',
#  'showed_planning_or_stealth']

# %%
# Drop Weapon Used Cd since we've engineered Weapon_Category
df_v4.drop(columns=['Weapon Used Cd'], inplace=True)
df_v4
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#          Vict Age  ...             Premis Desc  \
# 0              31  ...  SINGLE FAMILY DWELLING
# 1              32  ...                SIDEWALK
# 2              30  ...  SINGLE FAMILY DWELLING
# 3              47  ...                  STREET
# 4              63  ...                   ALLEY
# ...           ...  ...                     ...
# 1004986        35  ...                  STREET
# 1004987        11  ...  SINGLE FAMILY DWELLING
# 1004988        16  ...                  STREET
# 1004989        17  ...             HIGH SCHOOL
# 1004990        35  ...             HIGH SCHOOL
#
#                                          LOCATION      LAT       LON  \
# 0         7800    BEEMAN                       AV  34.2124 -118.4092
# 1                 ATOLL                        AV  34.1993 -118.4203
# 2        14600    SYLVAN                       ST  34.1847 -118.4509
# 3         6000    COMEY                        AV  34.0339 -118.3747
# 4                         4700    LA VILLA MARINA  33.9813 -118.4350
# ...                                           ...      ...       ...
# 1004986  22100    ROSCOE                       BL  34.2259 -118.6126
# 1004987   3500    PERCY                        ST  34.0277 -118.1979
# 1004988    300 E  53RD                         ST  33.9942 -118.2701
# 1004989   9600    ZELZAH                       AV  34.2450 -118.5233
# 1004990  11100    OMELVENY                     AV  34.2722 -118.4417
#
#          Vict_Sex_Clean Vict_Descent_Clean Weapon_Category  \
# 0                  Male           Hispanic            None
# 1                  Male           Hispanic    Edged Weapon
# 2                  Male              White            None
# 3                Female              Asian            None
# 4                  Male           Hispanic            None
# ...                 ...                ...             ...
# 1004986            Male      Other/Unknown            None
# 1004987            Male              Black            None
# 1004988          Female           Hispanic            None
# 1004989            Male           Hispanic    Bodily Force
# 1004990          Female           Hispanic            None
#
#         involved_physical_force  involved_victim_restraint  \
# 0                             0                          0
# 1                             1                          0
# 2                             0                          0
# 3                             0                          0
# 4                             0                          0
# ...                         ...                        ...
# 1004986                       0                          0
# 1004987                       0                          0
# 1004988                       0                          0
# 1004989                       1                          0
# 1004990                       0                          0
#
#          showed_planning_or_stealth
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
# ...                             ...
# 1004986                           0
# 1004987                           0
# 1004988                           0
# 1004989                           0
# 1004990                           0
#
# [735632 rows x 21 columns]

# %% [markdown]
# ## Incident Identifiers & Timestamps
# DR_NO: The unique report number that identifies a single crime incident.
#
# DATE OCC: The date the crime actually occurred. This is the primary column for creating your victim timeline.
#
# Date Rptd: The date the crime was reported to the police.
#
# TIME OCC: The time the crime occurred, in 24-hour military time format.
#
# ## Crime Descriptors
# Crm Cd: The numerical code for the specific type of crime.
#
# Crm Cd Desc: The text description of the crime (e.g., "BURGLARY FROM VEHICLE").
#
# Part 1-2: A classification of the crime's severity, where Part 1 crimes are generally more serious.
#
# Weapon_Category: Your engineered feature describing the type of weapon used (e.g., 'Firearm', 'Bodily Force', 'None').
#
# ## Location Information
# AREA: The numerical code for the police reporting district.
#
# AREA NAME: The name of the police reporting district (e.g., "Central").
#
# Premis Cd: The numerical code for the type of premise where the crime occurred.
#
# Premis Desc: The text description of the premise (e.g., "STREET", "SINGLE FAMILY DWELLING").
#
# LOCATION: The specific street address or intersection of the crime.
#
# LAT: The latitude coordinate for the crime location.
#
# LON: The longitude coordinate for the crime location.
#
# ## Victim Demographics
# Vict Age: The age of the victim.
#
# Vict_Sex_Clean: Your cleaned feature for the victim's sex ('Male', 'Female', 'Unknown/Other').
#
# Vict_Descent_Clean: Your cleaned feature for the victim's race/ethnicity.
#
# ## Engineered Behavioral Features
# These are the new features we created from the Mocodes column.
#
# involved_physical_force: A binary (1/0) feature indicating if the crime involved direct physical violence against the victim.
#
# involved_victim_restraint: A binary (1/0) feature indicating if the victim was bound, held, or otherwise restrained.
#
# showed_planning_or_stealth: A binary (1/0) feature indicating if the suspect used a disguise, stalked the victim, or showed other signs of premeditation.

# %% [markdown]
# # Creating the Vict ID through feature engineering

# %%
# First, ensure the 'DATE OCC' is a datetime object
df_v4['DATE OCC'] = pd.to_datetime(df_v4['DATE OCC'])

# Extract the year of the incident
df_v4['Incident_Year'] = df_v4['DATE OCC'].dt.year

# Calculate the approximate birth year
df_v4['Birth_Year'] = df_v4['Incident_Year'] - df_v4['Vict Age']

# %%
# Combine the stable features into a single string ID
df_v4['Victim_ID'] = (df_v4['Birth_Year'].astype(int).astype(str) + '-' +
                   df_v4['Vict_Sex_Clean'].astype(str) + '-' +
                   df_v4['Vict_Descent_Clean'].astype(str))

# Display a sample of the new IDs
print("Sample of generated Victim IDs:")
print(df_v4['Victim_ID'].head())
# Out:
# Sample of generated Victim IDs:
# 0    1989-Male-Hispanic
# 1    1988-Male-Hispanic
# 2       1990-Male-White
# 3     1973-Female-Asian
# 4    1957-Male-Hispanic
# Name: Victim_ID, dtype: object

# %%
# Count how many times each Victim_ID appears in the dataset
id_counts = df_v4['Victim_ID'].value_counts()

# Map these counts back to our main DataFrame
df_v4['Victim_Incident_Count'] = df_v4['Victim_ID'].map(id_counts)

# Create the final DataFrame containing ONLY repeat victims
repeat_victims_df = df_v4[df_v4['Victim_Incident_Count'] > 1].copy()

# Sort by victim and date to see their timelines clearly
repeat_victims_df.sort_values(by=['Victim_ID', 'DATE OCC'], inplace=True)

# Verify the result
print(f"\nOriginal dataset size: {len(df_v4)} rows")
print(f"Dataset of repeat victims: {len(repeat_victims_df)} rows")
print(f"Number of unique repeat victims: {repeat_victims_df['Victim_ID'].nunique()}")
# Out:
# Original dataset size: 735632 rows
# Dataset of repeat victims: 735566 rows
# Number of unique repeat victims: 1195

# %% [markdown]
# # Victim Info

# %%
# Create a new dataframe with the specified columns
vict_info = df_v4[['Birth_Year', 'Victim_ID', 'Victim_Incident_Count']].copy()

# Display the new dataframe
display(vict_info)
# Out:
#          Birth_Year                Victim_ID  Victim_Incident_Count
# 0              1989       1989-Male-Hispanic                   3819
# 1              1988       1988-Male-Hispanic                   3693
# 2              1990          1990-Male-White                   2742
# 3              1973        1973-Female-Asian                    143
# 4              1957       1957-Male-Hispanic                    858
# ...             ...                      ...                    ...
# 1004986        1990  1990-Male-Other/Unknown                   1552
# 1004987        2014          2014-Male-Black                     59
# 1004988        2009     2009-Female-Hispanic                   1007
# 1004989        2008       2008-Male-Hispanic                    788
# 1004990        1990     1990-Female-Hispanic                   4444
#
# [735632 rows x 3 columns]

# %%
df_v4
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0        211507896 2021-04-11 2020-11-07       845    15  N Hollywood
# 1        201516622 2020-10-21 2020-10-18      1845    15  N Hollywood
# 2        240913563 2024-12-10 2020-10-30      1240     9     Van Nuys
# 3        210704711 2020-12-24 2020-12-24      1310     7     Wilshire
# 4        201418201 2020-10-03 2020-09-29      1830    14      Pacific
# ...            ...        ...        ...       ...   ...          ...
# 1004986  252104112 2025-02-02 2025-02-02       130    21      Topanga
# 1004987  250404100 2025-02-18 2025-02-18      1000     4   Hollenbeck
# 1004988  251304095 2025-01-31 2025-01-30      1554    13       Newton
# 1004989  251704066 2025-01-17 2025-01-17      1600    17   Devonshire
# 1004990  251904210 2025-03-25 2025-03-25      1235    19      Mission
#
#          Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0               2     354                                  THEFT OF IDENTITY
# 1               1     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 2               2     354                                  THEFT OF IDENTITY
# 3               1     331  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...
# 4               1     420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# ...           ...     ...                                                ...
# 1004986         2     946                          OTHER MISCELLANEOUS CRIME
# 1004987         2     237                     CHILD NEGLECT (SEE 300 W.I.C.)
# 1004988         2     850                                  INDECENT EXPOSURE
# 1004989         2     624                           BATTERY - SIMPLE ASSAULT
# 1004990         2     850                                  INDECENT EXPOSURE
#
#          Vict Age  ...  Vict_Sex_Clean Vict_Descent_Clean Weapon_Category  \
# 0              31  ...            Male           Hispanic            None
# 1              32  ...            Male           Hispanic    Edged Weapon
# 2              30  ...            Male              White            None
# 3              47  ...          Female              Asian            None
# 4              63  ...            Male           Hispanic            None
# ...           ...  ...             ...                ...             ...
# 1004986        35  ...            Male      Other/Unknown            None
# 1004987        11  ...            Male              Black            None
# 1004988        16  ...          Female           Hispanic            None
# 1004989        17  ...            Male           Hispanic    Bodily Force
# 1004990        35  ...          Female           Hispanic            None
#
#          involved_physical_force  involved_victim_restraint  \
# 0                              0                          0
# 1                              1                          0
# 2                              0                          0
# 3                              0                          0
# 4                              0                          0
# ...                          ...                        ...
# 1004986                        0                          0
# 1004987                        0                          0
# 1004988                        0                          0
# 1004989                        1                          0
# 1004990                        0                          0
#
#         showed_planning_or_stealth Incident_Year Birth_Year  \
# 0                                0          2020       1989
# 1                                0          2020       1988
# 2                                0          2020       1990
# 3                                0          2020       1973
# 4                                0          2020       1957
# ...                            ...           ...        ...
# 1004986                          0          2025       1990
# 1004987                          0          2025       2014
# 1004988                          0          2025       2009
# 1004989                          0          2025       2008
# 1004990                          0          2025       1990
#
#                        Victim_ID  Victim_Incident_Count
# 0             1989-Male-Hispanic                   3819
# 1             1988-Male-Hispanic                   3693
# 2                1990-Male-White                   2742
# 3              1973-Female-Asian                    143
# 4             1957-Male-Hispanic                    858
# ...                          ...                    ...
# 1004986  1990-Male-Other/Unknown                   1552
# 1004987          2014-Male-Black                     59
# 1004988     2009-Female-Hispanic                   1007
# 1004989       2008-Male-Hispanic                    788
# 1004990     1990-Female-Hispanic                   4444
#
# [735632 rows x 25 columns]
